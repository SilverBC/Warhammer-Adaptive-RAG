# %% [markdown]
# The idea here is to pre-process .pdf files found on the GamesWorkshop oficcial website, so that they are more LLM friendly.

# %%
# !pip install -r requirements.txt  # uncomment and run if you wish to pull all the dependencies
# !pip install llama-parse          # uncomment and run if you only want to tweak the parser

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import os
import configparser
from llama_parse import LlamaParse

def load_config(file_path=".config"):
    config = configparser.ConfigParser()
    config.read(file_path)
    return config

def get_api_key(var, config):
    return config["DEFAULT"].get(var)

# Load the config file
config = load_config()

# Fetch the API keys
llamaParse_api_key = get_api_key("LLAMA_CLOUD_API_KEY", config)

os.environ["LLAMA_CLOUD_API_KEY"] = llamaParse_api_key
print(llamaParse_api_key)

# %%
import os
from llama_parse import LlamaParse

dir_location = "Documents/"
dest_location = "MarkdownDocs/"
parsing_instruction="""The document provides information on the Warhammer 40K tabletop game, including rules, attributes of playable units, and other essential details needed for gameplay.
                      Preserve the structure of the document, including headings, subheadings, and tables, and ensure no sections are skipped.
                      Maintain the integrity of tables and lists, and extract all details in full.
                      """

# Recursively go through all folders in dir_location
for root, dirs, files in os.walk(dir_location):
    for file in files:
        if file.endswith('.pdf'):
            pdf_path = os.path.join(root, file)

            document = LlamaParse(result_type="markdown",
                                  parsing_instruction=parsing_instruction
                                  ).load_data(pdf_path)
            
            combined_text = "".join([doc.text for doc in document])
            
            # Create the corresponding output directory in MarkdownDocs
            relative_folder_path = os.path.relpath(root, dir_location)
            output_folder = os.path.join(dest_location, relative_folder_path)
            os.makedirs(output_folder, exist_ok=True)

            md_file_name = file.replace('.pdf', '.md')
            md_file_path = os.path.join(output_folder, md_file_name)
            
            with open(md_file_path, "w", encoding="utf-8") as md_file:
                md_file.write(combined_text)
            
            print(f"Processed {pdf_path} and saved as {md_file_path}")
# Out:
# Started parsing the file under job_id 4f8ad8f3-c35b-4ec1-ab8a-744bfd53dcde
# Processed Documents/Armor-Tyranids.pdf and saved as MarkdownDocs/.\Armor-Tyranids.md
# Started parsing the file under job_id 8605f0b1-c33b-4b02-8ada-0df617667461
# .Processed Documents/Combat-Patrol-Tyranids.pdf and saved as MarkdownDocs/.\Combat-Patrol-Tyranids.md
# Started parsing the file under job_id 652a47f0-4011-420b-a57a-9e7a9164909d
# Processed Documents/Legends-Tyranids.pdf and saved as MarkdownDocs/.\Legends-Tyranids.md
# Started parsing the file under job_id b0eaab31-14d6-48f9-8ff5-80805ca610dd
# ...Processed Documents/Indexes-FAQs-Errata\AELDARI-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\AELDARI-ARMY-RULE.md
# Started parsing the file under job_id 71a77be6-a9e2-41f3-8862-7655b67c322e
# .Processed Documents/Indexes-FAQs-Errata\AGENTS-OF-THE-IMPERIUM-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\AGENTS-OF-THE-IMPERIUM-ARMY-RULE.md
# Started parsing the file under job_id a1846e4f-bd7e-45a1-adc3-0963912f3210
# ....Processed Documents/Indexes-FAQs-Errata\ASTRA-MILITARUM-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\ASTRA-MILITARUM-ARMY-RULE.md
# Started parsing the file under job_id dd358b8a-9ce7-4d34-bfa6-9f077276890d
# ..Processed Documents/Indexes-FAQs-Errata\BLACK TEMPLARS – RIGHTEOUS CRUSADERS-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\BLACK TEMPLARS – RIGHTEOUS CRUSADERS-ARMY-RULE.md
# Started parsing the file under job_id 8b8faf6a-039e-41fc-b575-5de83c8deaee
# ..Processed Documents/Indexes-FAQs-Errata\BLOOD-ANGELS – SONS OF SANGUINIUS-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\BLOOD-ANGELS – SONS OF SANGUINIUS-ARMY-RULE.md
# Started parsing the file under job_id 1a2bdbfb-89e0-490a-ae89-f5292ca88d1c
# ...Processed Documents/Indexes-FAQs-Errata\CHAOS-DAEMONS-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CHAOS-DAEMONS-ARMY-RULE.md
# Started parsing the file under job_id cce9fa79-1e9a-406b-93aa-ea220ce3ce25
# ..Processed Documents/Indexes-FAQs-Errata\CHAOS-KNIGHTS-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CHAOS-KNIGHTS-ARMY-RULE.md
# Started parsing the file under job_id d89307ae-b49f-4558-90c9-cfad68ae855f
# Processed Documents/Indexes-FAQs-Errata\CODEX-ADEPTA-SORORITAS.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CODEX-ADEPTA-SORORITAS.md
# Started parsing the file under job_id 5ee4d957-8fd2-484a-ae83-7bdc125ea8ef
# Processed Documents/Indexes-FAQs-Errata\CODEX-ADEPTUS-CUSTODES.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CODEX-ADEPTUS-CUSTODES.md
# Started parsing the file under job_id 42ef4fdc-76ee-4900-a535-4957394c2b82
# Processed Documents/Indexes-FAQs-Errata\CODEX-ADEPTUS-MECHANICUS.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CODEX-ADEPTUS-MECHANICUS.md
# Started parsing the file under job_id 24e56738-203f-4d1c-9837-3172e241d051
# .Processed Documents/Indexes-FAQs-Errata\CODEX-CHAOS-SPACE-MARINES.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CODEX-CHAOS-SPACE-MARINES.md
# Started parsing the file under job_id a734f4d9-e4b8-43b0-aaec-bbdb3c1b7981
# Processed Documents/Indexes-FAQs-Errata\CODEX-DARK-ANGELS.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CODEX-DARK-ANGELS.md
# Started parsing the file under job_id d82bc857-b271-4aab-8c11-355c644a8139
# Processed Documents/Indexes-FAQs-Errata\CODEX-GENESTEALER-CULTS.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CODEX-GENESTEALER-CULTS.md
# Started parsing the file under job_id 03380d87-6219-486d-aa52-8c480054a4b4
# Processed Documents/Indexes-FAQs-Errata\CODEX-NECRONS.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CODEX-NECRONS.md
# Started parsing the file under job_id 23c8c674-2968-4ba9-8d37-f93a89a753c6
# Processed Documents/Indexes-FAQs-Errata\CODEX-ORKS.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CODEX-ORKS.md
# Started parsing the file under job_id 8a51890a-3fab-46c5-b6cf-2c5eee7b2f19
# Processed Documents/Indexes-FAQs-Errata\CODEX-SPACE-MARINES.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CODEX-SPACE-MARINES.md
# Started parsing the file under job_id 9c7bc95c-26f2-4b25-b940-bcb4aaa5ea28
# Processed Documents/Indexes-FAQs-Errata\Codex-Tyranids.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\Codex-Tyranids.md
# Started parsing the file under job_id 15f005ce-ed4e-414d-ac58-f2bc65352ebc
# Processed Documents/Indexes-FAQs-Errata\CODEX-T’AU-EMPIRE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\CODEX-T’AU-EMPIRE.md
# Started parsing the file under job_id 6c0c8251-1cb4-494d-9942-89a57c00042b
# ...Processed Documents/Indexes-FAQs-Errata\DEATH-GUARD-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\DEATH-GUARD-ARMY-RULE.md
# Started parsing the file under job_id 80b672f8-35e8-4641-8122-7b30d711630b
# ....Processed Documents/Indexes-FAQs-Errata\DEATHWATCH-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\DEATHWATCH-ARMY-RULE.md
# Started parsing the file under job_id f4fd5955-6f2a-4dcb-9e99-978c488cee61
# ...Processed Documents/Indexes-FAQs-Errata\DRUKHARI-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\DRUKHARI-ARMY-RULE.md
# Started parsing the file under job_id 7177183b-0f0c-4805-8310-7048ecab8d2e
# .Processed Documents/Indexes-FAQs-Errata\EMPEROR’S-CHILDREN-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\EMPEROR’S-CHILDREN-ARMY-RULE.md
# Started parsing the file under job_id 65bf43d8-34ce-4845-ab3d-5a98ff6be843
# ...Processed Documents/Indexes-FAQs-Errata\GREY-KNIGHTS-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\GREY-KNIGHTS-ARMY-RULE.md
# Started parsing the file under job_id e3932cdf-e94d-4bec-b7b5-89c541b8e66d
# ..Processed Documents/Indexes-FAQs-Errata\IMPERIAL-KNIGHTS-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\IMPERIAL-KNIGHTS-ARMY-RULE.md
# Started parsing the file under job_id 96fb8ff3-73d3-4dbf-adbf-e855e715db88
# Processed Documents/Indexes-FAQs-Errata\Index-Cards.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\Index-Cards.md
# Started parsing the file under job_id a840d23f-4e0d-4a7e-9f99-b9324274d775
# ..Processed Documents/Indexes-FAQs-Errata\LEAGUES-OF-VOTANN-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\LEAGUES-OF-VOTANN-ARMY-RULE.md
# Error while parsing the file 'Documents/Indexes-FAQs-Errata\SPACE-WOLVES-ARMY-RULE.pdf': Failed to parse the file: {"detail":"You've exceeded the maximum number of pages you can parse in a day (1000). Please contact support to increase your limit."}
# Processed Documents/Indexes-FAQs-Errata\SPACE-WOLVES-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\SPACE-WOLVES-ARMY-RULE.md
# Error while parsing the file 'Documents/Indexes-FAQs-Errata\THOUSAND-SONS-ARMY-RULE.pdf': Failed to parse the file: {"detail":"You've exceeded the maximum number of pages you can parse in a day (1000). Please contact support to increase your limit."}
# Processed Documents/Indexes-FAQs-Errata\THOUSAND-SONS-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\THOUSAND-SONS-ARMY-RULE.md
# Error while parsing the file 'Documents/Indexes-FAQs-Errata\WORLD-EATERS-ARMY-RULE.pdf': Failed to parse the file: {"detail":"You've exceeded the maximum number of pages you can parse in a day (1000). Please contact support to increase your limit."}
# Processed Documents/Indexes-FAQs-Errata\WORLD-EATERS-ARMY-RULE.pdf and saved as MarkdownDocs/Indexes-FAQs-Errata\WORLD-EATERS-ARMY-RULE.md
# Error while parsing the file 'Documents/Key-Downloads\Balance-Dataslate.pdf': Failed to parse the file: {"detail":"You've exceeded the maximum number of pages you can parse in a day (1000). Please contact support to increase your limit."}
# Processed Documents/Key-Downloads\Balance-Dataslate.pdf and saved as MarkdownDocs/Key-Downloads\Balance-Dataslate.md
# Error while parsing the file 'Documents/Key-Downloads\Core-Rules-Updates.pdf': Failed to parse the file: {"detail":"You've exceeded the maximum number of pages you can parse in a day (1000). Please contact support to increase your limit."}
# Processed Documents/Key-Downloads\Core-Rules-Updates.pdf and saved as MarkdownDocs/Key-Downloads\Core-Rules-Updates.md
# Error while parsing the file 'Documents/Key-Downloads\Munitorum-Field-Manual.pdf': Failed to parse the file: {"detail":"You've exceeded the maximum number of pages you can parse in a day (1000). Please contact support to increase your limit."}
# Processed Documents/Key-Downloads\Munitorum-Field-Manual.pdf and saved as MarkdownDocs/Key-Downloads\Munitorum-Field-Manual.md
# Error while parsing the file 'Documents/Key-Downloads\Pariah-Nexus-Tournament-Companion.pdf': Failed to parse the file: {"detail":"You've exceeded the maximum number of pages you can parse in a day (1000). Please contact support to increase your limit."}
# Processed Documents/Key-Downloads\Pariah-Nexus-Tournament-Companion.pdf and saved as MarkdownDocs/Key-Downloads\Pariah-Nexus-Tournament-Companion.md
# Error while parsing the file 'Documents/Key-Downloads\Quick-Start-Guide.pdf': Failed to parse the file: {"detail":"You've exceeded the maximum number of pages you can parse in a day (1000). Please contact support to increase your limit."}
# Processed Documents/Key-Downloads\Quick-Start-Guide.pdf and saved as MarkdownDocs/Key-Downloads\Quick-Start-Guide.md
# Error while parsing the file 'Documents/Key-Downloads\warhammer_core_rules.pdf': Failed to parse the file: {"detail":"You've exceeded the maximum number of pages you can parse in a day (1000). Please contact support to increase your limit."}
# Processed Documents/Key-Downloads\warhammer_core_rules.pdf and saved as MarkdownDocs/Key-Downloads\warhammer_core_rules.md
